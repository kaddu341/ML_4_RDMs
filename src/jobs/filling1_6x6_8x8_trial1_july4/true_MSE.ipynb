# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots

# %%
plt.style.use(['science', 'notebook', 'grid'])

# %%
std_losses = np.array([4.412195226500949e-05, 4.45997863160243e-05, 0.0044539316468650385, 0.006895497736949769, 0.0115093540636793, 0.014258662164802588, 0.019422238190022725, 0.02322742904699038])

true_MSE = std_losses * (0.17026729881763458 ** 2)

dims = list(range(6, 21, 2))

# %%
plt.figure(figsize=(8, 3))
plt.plot(dims, true_MSE, '--s')
plt.xlabel("$L$")
plt.ylabel(r'$\log_{10}(\text{MSE})$')
plt.show()
